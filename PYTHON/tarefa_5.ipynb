# %%
 numeros = [1,2,3,4,5]
print(numeros)
# Out:
# [1, 2, 3, 4, 5]

# %%
 nomes = ["joao","maria","pedro","jose"]
print(nomes[0],",",nomes[3])
# Out:
# joao , jose

# %%
numeros = [1,2,3,4,5,6]

for numero in numeros:
    if numero % 2 ==0:
        print(numero)
# Out:
# 2
# 4
# 6

# %%
cor= input("digite uma cor: ")
cores = [ "preto","branco", "roxo", cor]
print(cores)
# Out:
# digite uma cor: rosa
# ['preto', 'branco', 'roxo', 'rosa']

# %%
frutas = ['banana', 'abacaxi', 'pera', 'maça', 'goiaba']
quantidade = len(frutas)
print(quantidade)
# Out:
# 5

# %%
numeros = [1,2,3,4,5,6,7]
print(numeros[0]+numeros[1]+numeros[2]+numeros[3]+numeros[4]+numeros[5]+numeros[6])
# Out:
# 28

# %%
numeros = [1,2,32,4,5,6]
maior = max(numeros)
menor = min(numeros)
print("o maior numero é: ", maior)
print("o menor numero é: ", menor)
# Out:
# o maior numero é:  32
# o menor numero é:  1

# %%
animal = 'javali'
animais = ['leao, gato, cachorro, cavalo',animal]
print(animais)
animal = input("digite um animal para entrar na lista: ")
animais = ['leao, gato, cachorro, cavalo',animal]
print(animais)
# Out:
# ['leao, gato, cachorro, cavalo', 'javali']
# digite um animal para entrar na lista: rosa
# ['leao, gato, cachorro, cavalo', 'rosa']

# %%
numeros = [1,2,3,4,5,6,7,8]
for numero in numeros:
    if numero % 2 == 0:
        print(end="")
    else:
        print(numero)
# Out:
# 1
# 3
# 5
# 7
