# %%
paragrafo = "Neste dia ensolarado, o sol brilhava forte, o sol aquecia a terra. As aves cantavam no céu azul, o céu era vasto e azul. A brisa suave balançava as árvores, as árvores dançavam ao vento."
arquivo = open("texto.txt","w")
arquivo.write(paragrafo)
arquivo.close()

# %%
arquivo = open("texto.txt","r")
conteudo = arquivo.read()
print(conteudo)
arquivo.close()
# Out:
# Neste dia ensolarado, o sol brilhava forte, o sol aquecia a terra. As aves cantavam no céu azul, o céu era vasto e azul. A brisa suave balançava as árvores, as árvores dançavam ao vento.

# %%
word_counts = Counter(words)

with open("frequencia.txt", "w") as arquivo_frequencia:
    for word, count in word_counts.items():
        arquivo_frequencia.write(f"{word};{count}\n")

print("Frequência das palavras contada e salva em 'frequencia.txt'.")
# Out:
# Frequência das palavras contada e salva em 'frequencia.txt'.

# %%
arquivo =open("frequencia.txt","r")
conteudo = arquivo.read()
print(conteudo)
arquivo.close()
# Out:
# neste;1
# dia;1
# ensolarado;1
# o;3
# sol;2
# brilhava;1
# forte;1
# aquecia;1
# a;2
# terra;1
# as;3
# aves;1
# cantavam;1
# no;1
# céu;2
# azul;2
# era;1
# vasto;1
# e;1
# brisa;1
# suave;1
# balançava;1
# árvores;2
# dançavam;1
# ao;1
# vento;1
