# %%
num1= int(input("diga o primeiro numero:"))
num2= int(input("diga o segundo numero:"))
num3= int(input("diga o terceiro numero:"))

soma= num1 + num2 + num3
media= soma/3

print("a media dos numeros é:", media)
# Out:
# diga o primeiro numero:10
# diga o segundo numero:10
# diga o terceiro numero:10
# a media dos numeros é: 10.0
