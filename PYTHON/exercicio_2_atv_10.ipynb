# %%
paragrafo = "Neste dia ensolarado, o sol brilhava forte, o sol aquecia a terra. As aves cantavam no céu azul, o céu era vasto e azul. A brisa suave balançava as árvores, as árvores dançavam ao vento."
arquivo = open("mensagem.txt","w")
arquivo.write(paragrafo)
arquivo.close()

# %%
from collections import Counter
import re

letras = re.findall(r'[a-z]', conteudo.lower())

letter_counts = Counter(letras)

print("Frequência das letras:")
for letra, count in letter_counts.items():
    print(f"{letra}: {count}")
# Out:
# Frequência das letras:
# n: 7
# e: 13
# s: 13
# t: 6
# d: 3
# i: 4
# a: 31
# o: 14
# l: 7
# r: 11
# b: 3
# h: 1
# v: 10
# f: 1
# q: 1
# u: 6
# c: 4
# m: 2
# z: 2
